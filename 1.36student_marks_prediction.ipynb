# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
data = {
    'Hours': [1,2,3,4,5,6,7,8],
    'Marks': [20,30,35,50,55,65,70,90]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Hours  Marks
# 0      1     20
# 1      2     30
# 2      3     35
# 3      4     50
# 4      5     55
# 5      6     65
# 6      7     70
# 7      8     90

# %%
plt.scatter(df['Hours'], df['Marks'])
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Hours vs Marks")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

X = df[['Hours']]
y = df['Marks']

model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
prediction = model.predict([[6.5]])

print("Predicted Marks:", prediction)
# Out:
# Predicted Marks: [70.56547619]
# C:\Users\ANOOP\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(df['Hours'], df['Marks'])

plt.plot(df['Hours'], model.predict(X))

plt.xlabel("Hours")
plt.ylabel("Marks")

plt.show()

# %%
prediction = model.predict(
    pd.DataFrame([[2],[4],[6.5],[8]], columns=['Hours'])
)

print(prediction)
# Out:
# [28.51190476 47.20238095 70.56547619 84.58333333]
